# %%
import numpy as np 
import pandas as pd
np.set_printoptions(suppress=True)

data_tot = np.load('raw_data/vsdata.npy')
m,N,l = data_tot.shape
n = int(N/8)
data_tot = data_tot.reshape(m,9,n,3)
# print(data_tot.shape)
data_mean = data_tot.mean(axis=2).T
data_std = data_tot.std(axis=2).T
# print(data_mean[2])
ref_ = np.load('raw_data/refdata.npy')
ref_mean = (ref_[:,1:].reshape(9,5,3).mean(axis=1))
formatted_data = np.zeros((9,15))
formatted_data[:,0] = ref_mean[:,0]
formatted_data[:,1] = ref_mean[:,2]
formatted_data[:,2] = ref_mean[:,1]
for i in range(6):
    formatted_data[:,3+i*2] = data_mean[2,:,i]
    formatted_data[:,3+i*2+1] = data_mean[1,:,i]
formatted_data =formatted_data.round(3).astype(str)
# formatted_data = np.char.add(np.char.add(data_mean.round(2).astype(str), '±'), data_std.round(2).astype(str))
# formatted_data =data_mean.round(4).astype(str)
column_names = ['Ref.','random_num','random_hv','nsga2_num','nsga2_hv','nsga3_num','nsga3_hv','moead_num','moead_hv','rvea_num','rvea_hv','NI-bSB_num','NI-bSB_hv','NI-dSB_num','NI-dSB_hv']  
row_names = ['n=15,d=0.5','n=15,d=1.0','n=20,d=0.5','n=20,d=1.0','ibm','n=100,d=0.5','n=100,d=1','n=200,d=0.5','n=200,d=1.0'] 
df = pd.DataFrame(formatted_data, index = row_names,columns=column_names)
# df.to_csv('table1.csv', index=True,encoding='utf-8-sig')
print(df)
# Out:
#                Ref. random_num random_hv nsga2_num nsga2_hv nsga3_num  \
# n=15,d=0.5    182.0        8.8     0.813     150.4    0.995      82.4
# n=15,d=1.0    101.0        5.6     0.828     100.6      1.0      61.0
# n=20,d=0.5    495.0        0.6      0.71     144.4    0.976      91.0
# n=20,d=1.0    367.0        0.4     0.698     159.2    0.988      87.8
# ibm          2067.0        0.0     0.497      35.0    0.956      61.2
# n=100,d=0.5  5794.2        0.0     0.154       7.4     0.65       9.2
# n=100,d=1    5358.8        0.0     0.155       1.4    0.594      27.4
# n=200,d=0.5  3758.0        0.0     0.105      21.2    0.562      60.2
# n=200,d=1.0  2066.0        0.0     0.123      28.6    0.623      78.8
#
#             nsga3_hv moead_num moead_hv rvea_num rvea_hv NI-bSB_num NI-bSB_hv  \
# n=15,d=0.5     0.973      47.6    0.875     39.2   0.918      182.0       1.0
# n=15,d=1.0     0.985      28.8    0.888     23.6   0.936      101.0       1.0
# n=20,d=0.5     0.962      40.0    0.794     28.0   0.904      495.0       1.0
# n=20,d=1.0     0.971      37.8    0.796     27.4   0.904      366.0       1.0
# ibm            0.949       3.2     0.84     11.0   0.916     2067.0       1.0
# n=100,d=0.5    0.742       0.0    0.399      0.6   0.551     3016.8     0.979
# n=100,d=1      0.782       0.0    0.384      0.4   0.584     2830.8      0.98
# n=200,d=0.5    0.778       0.0    0.284      4.8   0.592     1543.4     0.922
# n=200,d=1.0    0.831       0.2    0.345     15.0   0.653      755.6     0.864
#
#             NI-dSB_num NI-dSB_hv
# n=15,d=0.5       182.0       1.0
# n=15,d=1.0       101.0       1.0
# n=20,d=0.5       495.0       1.0
# n=20,d=1.0       366.0       1.0
# ibm             2067.0       1.0
# n=100,d=0.5     4133.4     0.994
# n=100,d=1       3726.0     0.994
# n=200,d=0.5     2463.2     0.976
# n=200,d=1.0     1321.2     0.947
